# %%
# !pip install xlrd -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 6.0 MB/s
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# Successfully installed xlrd-2.0.1

# %%
# !pip install hazm
#from __future__ import unicode_literals
from hazm import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 30.9 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 79.9 MB/s
# Collecting libwapiti>=0.2.1
#   Downloading libwapiti-0.2.1.tar.gz (233 kB)
#      |████████████████████████████████| 233 kB 45.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm) (1.15.0)
# Building wheels for collected packages: nltk, libwapiti
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394486 sha256=96d6e125791f84e28803623173e20fd52ffcf9c3be04b0e4798e56b5b24ae93b
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/0c/d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp37-cp37m-linux_x86_64.whl size=154228 sha256=126e5529b92ea93af13a9a02be5e874bbeeacbe01da64b6592ad018c9362800a
#   Stored in directory: /root/.cache/pip/wheels/ab/b2/5b/0fe4b8f5c0e65341e8ea7bb3f4a6ebabfe8b1ac31322392dbf
# Successfully built nltk libwapiti
# Installing collected packages: nltk, libwapiti, hazm
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3

# %%
import pandas as pd
import numpy as np
import datetime
import random
import time
from collections import Counter

import re



from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from torch.utils.data import TensorDataset, random_split

from imblearn.under_sampling import RandomUnderSampler 
from imblearn.datasets import make_imbalance

from tqdm import tqdm
import gc

import pickle




import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer 
from nltk.stem import *
nltk.download('punkt')


from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence


from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report



import keras
from keras import optimizers
from keras import backend as K
import tensorflow as tf
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional,Lambda
from tensorflow.keras.utils import to_categorical
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping

from scipy.spatial.distance import cosine
from tensorflow.keras.losses import cosine_similarity


from keras.utils.data_utils import pad_sequences
from torch.nn.utils.rnn import pack_padded_sequence
import torch.nn.functional as F


import os
import random
import tensorflow as tf
from keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping


from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
ran=random.sample(range(1000, 100000), 10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)


def text_preprocessing(text):
    """
    - Remove entity mentions (eg. '@united')
    - Correct errors (eg. '&amp;' to '&')
    @param    text (str): a string to be processed.
    @return   text (Str): the processed string.
    """
    # Remove '@name'
    text = re.sub(r'(@.*?)[\s]', ' ', text)

    # Replace '&amp;' with '&'
    text = re.sub(r'&amp;', '&', text)
    
    # Remove URL
    text = re.sub(r"http\S+", "", text)
    
    # Remove Hashtag
    text = re.sub(r"#\S+", "", text)

    # Remove trailing whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove non character 
    text=re.sub(r'[\W_]+',' ', text)
    text=deEmojify(text)

    # Remove  number
    text = re.sub(" \d+", " ", text)

    text = re.sub("just", " ", text)
    text = re.sub("right", " ", text)
    '''


    output = re.sub(r'\s*[A-Za-z]+\b', '' , text)
    text = output.rstrip()

    persian = ['۰', '۱', '۲', '۳', '۴', '۵', '۶', '۷', '۸', '۹'];
    for u in persian:
        text = re.sub(u, "", text);

  
    
    #
    #text = re.sub("کرونا", " ", text)
    #text = re.sub("ویروس", " ", text)
  
    '''
    return text

# %%
stop_words=[]
with open('./drive/MyDrive/stop-words.txt') as file:
    for line in file:
      stop_words.append(line.rstrip())

# %%
"""
Created on Tue Aug 16 14:43:05 2022

@author: behnam
"""

def flat_list(a):
    aa=[]
    for j in range(len(a)):
        
        aa=aa+a[j].split(',')
    return aa    
        
def text_preprocessing2(text):
    """
    - Remove entity mentions (eg. '@united')
    - Correct errors (eg. '&amp;' to '&')
    @param    text (str): a string to be processed.
    @return   text (Str): the processed string.
    """
    # Remove '@name'
    text = re.sub(r'(@.*?)[\s]', ' ', text)

    # Replace '&amp;' with '&'
    text = re.sub(r'&amp;', '', text)
    
    # Remove URL
    text = re.sub(r"http\S+", "", text)
    
    # Remove Hashtag
    text = re.sub(r"#\S+", "", text)
    
    # Remove Hashtag
    text = re.sub(r"&\S+", "", text)

    # Remove trailing whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    text=re.sub("[\(\[].*?[\)\]]", "", text)

    return text
    text = re.sub(r'\s+', ' ', text).strip()
    
    text=re.sub("[\(\[].*?[\)\]]", "", text)

    return text

# %%
pmfd=pd.read_excel('./drive/MyDrive/balanced_pmftc.xlsx')

# %%
# http://vectors.nlpl.eu/repository/
# !wget  http://vectors.nlpl.eu/repository/20/148.zip
# !unzip 148.zip
# Out:
# --2022-11-03 09:47:23--  http://vectors.nlpl.eu/repository/20/148.zip
# Resolving vectors.nlpl.eu (vectors.nlpl.eu)... 129.240.189.181
# Connecting to vectors.nlpl.eu (vectors.nlpl.eu)|129.240.189.181|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 405392550 (387M) [application/zip]
# Saving to: ‘148.zip’
#
# 148.zip             100%[===================>] 386.61M  27.4MB/s    in 15s
#
# 2022-11-03 09:47:39 (25.8 MB/s) - ‘148.zip’ saved [405392550/405392550]
#
# Archive:  148.zip
#   inflating: char.dic
#   inflating: config.json
#   inflating: encoder.pkl
#   inflating: meta.json
#   inflating: README
#   inflating: token_embedder.pkl
#   inflating: word.dic

# %%
! git clone https://github.com/HIT-SCIR/ELMoForManyLangs.git
# Out:
# Cloning into 'ELMoForManyLangs'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 212 (delta 9), reused 22 (delta 5), pack-reused 174
# Receiving objects: 100% (212/212), 125.80 KiB | 20.97 MiB/s, done.
# Resolving deltas: 100% (96/96), done.

# %% [markdown]
# change line 47 of highway.py(ELMoForManyLangs/elmoformanylangs/modules/highway.py) to this :
#
# def forward(self, *input: torch.Tensor) -> None:  # pylint: disable=arguments-differ
#         current_input = input[0]

# %%
# !pip install -e ELMoForManyLangs/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/ELMoForManyLangs
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from elmoformanylangs==0.0.4.post2) (1.12.1+cu113)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from elmoformanylangs==0.0.4.post2) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from elmoformanylangs==0.0.4.post2) (1.21.6)
# Collecting overrides
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->elmoformanylangs==0.0.4.post2) (1.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->elmoformanylangs==0.0.4.post2) (4.1.1)
# Installing collected packages: overrides, elmoformanylangs
#   Running setup.py develop for elmoformanylangs
# Successfully installed elmoformanylangs-0.0.4.post2 overrides-7.3.1

# %%
cd ELMoForManyLangs
# Out:
# /content/ELMoForManyLangs

# %%
from elmoformanylangs import Embedder

# %%
cd ..
# Out:
# /content

# %%
embed = Embedder('/content')
# Out:
# WARNING:elmoformanylangs:Could not find config.  Trying /content/cnn_50_100_512_4096_sample.json
# WARNING:elmoformanylangs:Could not find config.  Trying /content/ELMoForManyLangs/elmoformanylangs/configs/cnn_50_100_512_4096_sample.json
# INFO:elmoformanylangs:char embedding size: 2264
# INFO:elmoformanylangs:word embedding size: 148521
# INFO:elmoformanylangs:Model(
#   (token_embedder): ConvTokenEmbedder(
#     (word_emb_layer): EmbeddingLayer(
#       (embedding): Embedding(148521, 100, padding_idx=3)
#     )
#     (char_emb_layer): EmbeddingLayer(
#       (embedding): Embedding(2264, 50, padding_idx=2261)
#     )
#     (convolutions): ModuleList(
#       (0): Conv1d(50, 32, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(50, 32, kernel_size=(2,), stride=(1,))
#       (2): Conv1d(50, 64, kernel_size=(3,), stride=(1,))
#       (3): Conv1d(50, 128, kernel_size=(4,), stride=(1,))
#       (4): Conv1d(50, 256, kernel_size=(5,), stride=(1,))
#       (5): Conv1d(50, 512, kernel_size=(6,), stride=(1,))
#       (6): Conv1d(50, 1024, kernel_size=(7,), stride=(1,))
#     )
#     (highways): Highway(
#       (_layers): ModuleList(
#         (0): Linear(in_features=2048, out_features=4096, bias=True)
#         (1): Linear(in_features=2048, out_features=4096, bias=True)
#       )
#     )
#     (projection): Linear(in_features=2148, out_features=512, bias=True)
#   )
#   (encoder): ElmobiLm(
#     (forward_layer_0): LstmCellWithProjection(
#       (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#       (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#       (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#     )
#     (backward_layer_0): LstmCellWithProjection(
#       (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#       (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#       (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#     )
#     (forward_layer_1): LstmCellWithProjection(
#       (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#       (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#       (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#     )
#     (backward_layer_1): LstmCellWithProjection(
#       (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#       (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#       (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#     )
#   )
# )

# %%
def rescale(x)  :
  # rescale vectors to a desired range

  if not all(x == 0): # non all-zero vector
      # linear rescale to range [0, 1]
      x -= x.min() # bring the lower range to 0
      x /= x.max() # bring the upper range to 1
      # linear rescale to range [-1, 1]
      x = 2*x - 1
      return x

# %%
def elmo_embed (word):
   return rescale(embed.sents2elmo([[word]])[0][0])

# %%
foundation='Purity'

# %%
foundation_annot_inClass=pmfd[pmfd['Label']==foundation]
foundation_annot_outClass=pmfd[pmfd['Label']!=foundation]
x_inClass=foundation_annot_inClass['Tweet']
x_outClass=foundation_annot_outClass['Tweet']
y_inClass=len(x_inClass)*[1]
y_outClass=len(x_outClass)*[0]
x=x_inClass.tolist()+x_outClass.tolist()
y=y_inClass+y_outClass

# %%
rus = RandomUnderSampler(random_state=42)
#rus = RandomUnderSampler(sampling_strategy={0: 500, 1: 500 },random_state=42)
x_res, y_res = rus.fit_resample(np.asarray(x).reshape(-1, 1),y)

print('Original dataset shape %s' % Counter(y))
print('Resampled dataset shape %s' % Counter(y_res))

x_res=x_res.reshape(len(x_res))
# Out:
# Original dataset shape Counter({0: 7500, 1: 500})
# Resampled dataset shape Counter({0: 500, 1: 500})

# %%
from sklearn.utils import shuffle

word_seq=[]
sw_removed_texts = []
for doc in tqdm(x_res):
  tokens = word_tokenize(doc)
  filtered = [word for word in tokens if word not in stop_words] 
  #sw_removed_texts.append(" ".join(filtered))
  word_seq.append(filtered)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1655.44it/s]

# %%
max_seq_len=64
MAX_NB_WORDS=100000

from sklearn.utils import shuffle

sw_removed_texts = []
for doc in tqdm(x_res):
  tokens = word_tokenize(doc)
  filtered = [word for word in tokens if word not in stop_words]
46it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  98%|█████████▊| 5557/5645 [08:28<00:09,  9.39it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  98%|█████████▊| 5558/5645 [08:28<00:09,  9.48it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  98%|█████████▊| 5559/5645 [08:28<00:09,  8.93it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  98%|█████████▊| 5560/5645 [08:28<00:09,  8.52it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5562/5645 [08:29<00:09,  9.15it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5563/5645 [08:29<00:09,  8.95it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5564/5645 [08:29<00:08,  9.11it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5565/5645 [08:29<00:09,  8.86it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5566/5645 [08:29<00:08,  8.92it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5567/5645 [08:29<00:08,  8.84it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5568/5645 [08:29<00:08,  8.84it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5569/5645 [08:29<00:08,  9.04it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5570/5645 [08:30<00:08,  9.08it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5571/5645 [08:30<00:08,  8.62it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5573/5645 [08:30<00:07,  9.21it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▊| 5574/5645 [08:30<00:07,  9.25it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5575/5645 [08:30<00:07,  9.33it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5576/5645 [08:30<00:07,  9.11it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5577/5645 [08:30<00:07,  9.12it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5578/5645 [08:30<00:07,  8.97it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5579/5645 [08:31<00:07,  8.50it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5580/5645 [08:31<00:08,  7.94it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5581/5645 [08:31<00:08,  7.87it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5582/5645 [08:31<00:07,  8.07it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5583/5645 [08:31<00:07,  8.51it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5584/5645 [08:31<00:06,  8.85it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5586/5645 [08:31<00:06,  9.69it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5587/5645 [08:31<00:05,  9.70it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5589/5645 [08:32<00:05, 10.09it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5590/5645 [08:32<00:05,  9.98it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5592/5645 [08:32<00:05, 10.33it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5594/5645 [08:32<00:04, 10.46it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5596/5645 [08:32<00:04, 10.61it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5598/5645 [08:32<00:04, 10.74it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5600/5645 [08:33<00:04, 10.68it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5602/5645 [08:33<00:03, 10.78it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5604/5645 [08:33<00:03, 10.87it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5606/5645 [08:33<00:03, 10.85it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5608/5645 [08:33<00:03, 10.64it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5610/5645 [08:34<00:03, 10.61it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5612/5645 [08:34<00:03, 10.68it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5614/5645 [08:34<00:02, 10.61it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
#  99%|█████████▉| 5616/5645 [08:34<00:02, 10.62it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5618/5645 [08:34<00:02, 10.75it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5620/5645 [08:35<00:02, 10.75it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5622/5645 [08:35<00:02, 10.70it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5624/5645 [08:35<00:01, 10.66it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5626/5645 [08:35<00:01, 10.61it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5628/5645 [08:35<00:01, 10.58it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5630/5645 [08:35<00:01, 10.59it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5632/5645 [08:36<00:01, 10.71it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5634/5645 [08:36<00:01, 10.67it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5636/5645 [08:36<00:00, 10.57it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5638/5645 [08:36<00:00, 10.58it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5640/5645 [08:36<00:00, 10.63it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5642/5645 [08:37<00:00, 10.80it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|█████████▉| 5644/5645 [08:37<00:00, 10.94it/s]INFO:elmoformanylangs:1 batches, avg len: 3.0
# 100%|██████████| 5645/5645 [08:37<00:00, 10.91it/s]

# %%
embed_dim=1024
words_not_found = []
nb_words = min(MAX_NB_WORDS, len(word_index)+1)
print(nb_words)
embedding_matrix = np.zeros((nb_words, embed_dim))
for word, i in word_index.items():
  if i >= nb_words:
     continue
  embedding_vector = embeddings_vectors.get(word)
  
  if (embedding_vector is not None) and len(embedding_vector) > 0:
     embedding_matrix[i] = embedding_vector
  else:
     words_not_found.append(word)
print('number of null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# 5646
# number of null word embeddings: 15

# %%
def set_reproducible(seed):
  

  os.environ['PYTHONHASHSEED'] = str(0)
  # For working on GPUs from "TensorFlow Determinism"
  os.environ['CUDA_VISBLE_DEVICE'] = ''
  #np.random.seed(seed)
  random.seed(seed)
  tf.random.set_seed(seed)

# %%
def get_model():

  
  model = tf.keras.Sequential()

  model.add(Embedding(nb_words, embed_dim, input_length=max_seq_len, weights=[embedding_matrix],trainable=False))
  model.add(tf.keras.layers.LayerNormalization(axis=1)) 
  model.add(Bidirectional(LSTM(16, return_sequences= True)))
  model.add(Bidirectional(LSTM(8, return_sequences= False)))
  model.add(Dense(64,activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(1,activation='sigmoid'))

  #model.summary()

  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  es_callback = EarlyStopping(monitor='val_loss', patience=3)
  return model

# %%
f_binary_all=[]
f_macro_all=[]
f_micro_all=[]
p_all =[]
r_all=[]
fold = 0


for k in ran:

  fold+=1
  x_train_a, x_test_a, y_train_a, y_test_a =train_test_split(word_seq,np.asanyarray(y_res), test_size=0.3, random_state=k)

  set_reproducible(k)
  model=get_model()
  es_callback = EarlyStopping(monitor='val_loss', patience=3)
  history = model.fit(x_train_a, y_train_a, batch_size=32, epochs=200,verbose=1, validation_split=0.2, callbacks=[es_callback], shuffle=True)

  yhat=model.predict(x_test_a, verbose=0)

  yp=[]
  for k in range(len(yhat)):
    if yhat[k][0]>0.45:
      yp.append(1)
    else:
      yp.append(0)

  print(classification_report(y_test_a,yp))   
  print('F1-score for fold: %d :' %fold)
  f1_macro=f1_score(y_test_a,yp,average='macro')
  f1_binary=f1_score(y_test_a,yp,average='binary')
  f1_micro=f1_score(y_test_a,yp,average='micro')

  print(f1_binary)
  print('-----') 
  f_binary_all.append(f1_binary)

  print(f1_macro)
  print('-----') 
  f_macro_all.append(f1_macro)

  print(f1_micro)
  print('-----') 
  f_micro_all.append(f1_micro)

  print('Recall-score for fold: %d :' %fold)
  r=recall_score(y_test_a,yp)
  print(r)
  print('-----')
  print('Precision-score for fold: %d :' %fold)
  p=precision_score(y_test_a,yp)
  print(p)
  print('-----')
  print('----------------------------------------------')

  r_all.append(r)
  p_all.append(p)
 

print("Average of F1_binary_Score = {}".format(np.mean(f_binary_all)))
print("Standard Deviation of F1_binary_Score = {}".format(np.std(f_binary_all)))
print('------')

print("Average of F1_macro_Score = {}".format(np.mean(f_macro_all)))
print("Standard Deviation of F1_macro_Score = {}".format(np.std(f_macro_all)))
print('------')

print("Average of F1_micro_Score = {}".format(np.mean(f_micro_all)))
print("Standard Deviation of F1_micro_Score = {}".format(np.std(f_micro_all)))
print('------')

print("Average of Recall_Score = {}".format(np.mean(r_all)))
print("Standard Deviation of Recall_Score = {}".format(np.std(r_all)))
print('------')

print("Average of Precision_Score = {}".format(np.mean(p_all)))
print("Standard Deviation of Precision_Score = {}".format(np.std(p_all)))
print('------')
# Out:
# Epoch 1/200
